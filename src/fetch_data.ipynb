# %%
# !pip install wandb

# %%
import wandb
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a251092e-31c2-4e4e-912b-9e5b1e33709f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a251092e-31c2-4e4e-912b-9e5b1e33709f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bank-full.csv to bank-full.csv
# User uploaded file "bank-full.csv" with length 4610348 bytes

# %%
import pandas as pd

# read the dataset to a Pandas' dataframe
income = pd.read_csv("bank-full.csv", delimiter=';')
income.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
income.to_csv("raw_data.csv",index=False)

# %%
# Login to Weights & Biases
# !wandb login --relogin
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# Send the raw_data.csv to the Wandb storing it as an artifact
# !wandb artifact put \
      --name decision_tree/raw_data.csv \
      --type raw_data \
      --description "The raw data from bank marketing" raw_data.csv
# Out:
# wandb: Uploading file raw_data.csv to: "araujo-marcos/decision_tree/raw_data.csv:latest" (raw_data)
# wandb: Currently logged in as: araujo-marcos. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /content/wandb/run-20220602_125008-3h7ag9j8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sweet-puddle-18
# wandb: ⭐️ View project at https://wandb.ai/araujo-marcos/decision_tree
# wandb: 🚀 View run at https://wandb.ai/araujo-marcos/decision_tree/runs/3h7ag9j8
# Artifact uploaded, use this artifact in a run by adding:
#
#     artifact = run.use_artifact("araujo-marcos/decision_tree/raw_data.csv:latest")
#
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Synced sweet-puddle-18: https://wandb.ai/araujo-marcos/decision_tree/runs/3h7ag9j8
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220602_125008-3h7ag9j8/logs

# %%
#end
