# %%
# !pip install wandb

# %%
import wandb
import pandas as pd

# %%
# Login to Weights & Biases
# !wandb login --relogin
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
input_artifact="decision_tree/raw_data.csv:latest"
artifact_name="preprocessed_data.csv"
artifact_type="clean_data"
artifact_description="Data after preprocessing"

# %%
# create a new job_type
run = wandb.init(project="decision_tree", job_type="process_data")
# Out:
# wandb: Currently logged in as: araujo-marcos. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220602_141219-24q5gsoa</code>
# Syncing run <strong><a href="https://wandb.ai/araujo-marcos/decision_tree/runs/24q5gsoa" target="_blank">swept-lake-20</a></strong> to <a href="https://wandb.ai/araujo-marcos/decision_tree" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# donwload the latest version of artifact raw_data.csv
artifact = run.use_artifact(input_artifact)

# create a dataframe from the artifact
df = pd.read_csv(artifact.file())

# %%
# Delete duplicated rows
df.drop_duplicates(inplace=True)

# Generate a "clean data file"
df.to_csv(artifact_name,index=False)

# %%
# Create a new artifact and configure with the necessary arguments
artifact = wandb.Artifact(name=artifact_name,
                          type=artifact_type,
                          description=artifact_description)
artifact.add_file(artifact_name)
# Out:
# <ManifestEntry digest: PEf0GLzgaYbFa8V+tv7KzA==>

# %%
# Upload the artifact to Wandb
run.log_artifact(artifact)

# %%
# close the run
# waiting a while after run the previous cell before execute this
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.535 MB of 3.535 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">swept-lake-20</strong>: <a href="https://wandb.ai/araujo-marcos/decision_tree/runs/24q5gsoa" target="_blank">https://wandb.ai/araujo-marcos/decision_tree/runs/24q5gsoa</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220602_141219-24q5gsoa/logs</code>
